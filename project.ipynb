# %%
# %matplotlib inline

# %%
from tsp_problems import create_tsp_graph_3nodes
from qaoa_solution import solve_tsp_with_qaoa

if __name__ == "__main__":
    optimal_path, total_distance = solve_tsp_with_qaoa(create_tsp_graph_3nodes)
# Out:
# Initial TSP Graph:
# QAOA Result Details:
# Result type: <class 'qiskit.algorithms.minimum_eigen_solvers.vqe.VQEResult'>
# Available attributes: ['__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_aux_operator_eigenvalues', '_cost_function_evals', '_eigenstate', '_eigenvalue', '_optimal_circuit', '_optimal_parameters', '_optimal_point', '_optimal_value', '_optimizer_evals', '_optimizer_result', '_optimizer_time', 'aux_operator_eigenvalues', 'combine', 'cost_function_evals', 'eigenstate', 'eigenvalue', 'optimal_circuit', 'optimal_parameters', 'optimal_point', 'optimal_value', 'optimizer_evals', 'optimizer_result', 'optimizer_time']
# Eigenstate type: <class 'dict'>
#
# QAOA Results:
# Optimal path: A -> C -> B -> A
# Total distance: 7
#
# Optimal Path Visualization:

# %%
from tsp_problems import create_tsp_graph_4nodes
from qaoa_solution import solve_tsp_with_qaoa

if __name__ == "__main__":
    optimal_path, total_distance = solve_tsp_with_qaoa(create_tsp_graph_4nodes)
# Out:
# Initial TSP Graph:
# QAOA Result Details:
# Result type: <class 'qiskit.algorithms.minimum_eigen_solvers.vqe.VQEResult'>
# Available attributes: ['__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_aux_operator_eigenvalues', '_cost_function_evals', '_eigenstate', '_eigenvalue', '_optimal_circuit', '_optimal_parameters', '_optimal_point', '_optimal_value', '_optimizer_evals', '_optimizer_result', '_optimizer_time', 'aux_operator_eigenvalues', 'combine', 'cost_function_evals', 'eigenstate', 'eigenvalue', 'optimal_circuit', 'optimal_parameters', 'optimal_point', 'optimal_value', 'optimizer_evals', 'optimizer_result', 'optimizer_time']
# Eigenstate type: <class 'dict'>
#
# QAOA Results:
# Optimal path: B -> C -> A -> D -> B
# Total distance: 9
#
# Optimal Path Visualization:

# %%
from tsp_problems import create_tsp_graph_5nodes
from qaoa_solution import solve_tsp_with_qaoa

if __name__ == "__main__":
    optimal_path, total_distance = solve_tsp_with_qaoa(create_tsp_graph_5nodes)
# Out:
# Initial TSP Graph:
